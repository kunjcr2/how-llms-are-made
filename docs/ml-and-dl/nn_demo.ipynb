# %%
import torch

# %%
def sm(tn):
    return torch.nn.functional.softmax(tn)

# %%
input = torch.tensor([10.02, 4.62])
input_2 = input - torch.max(input)

# %%
print(input)
sm(input_2)
# Out:
# tensor([10.0200,  4.6200])
# C:\Users\kunjs\AppData\Local\Temp\ipykernel_14360\4034785328.py:2: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return torch.nn.functional.softmax(tn)
# tensor([0.9955, 0.0045])
